# %% [markdown]
# <a href="https://colab.research.google.com/github/dhassan24/Bioinformatics_Tools/blob/main/REVP_Restriction_Sites_Rosalind.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem
#
# Figure 2. Palindromic recognition site
# A DNA string is a reverse palindrome if it is equal to its reverse complement. For instance, GCATGC is a reverse palindrome because its reverse complement is GCATGC. See Figure 2.
#
# Given: A DNA string of length at most 1 kbp in FASTA format.
#
# Return: The position and length of every reverse palindrome in the string having length between 4 and 12. You may return these pairs in any order.

# %%
#Start with a DNA sequence: ATCAGTCATC
#Get the reverse complement: reverse_complement(dna_sequence)

#Find all strings in the reverse complement that equal DNA sequence:

#positions = [match.start() for match in re.finditer(substring, s)]

#Then return position + length of match

# %%
def reverse_complement(dna_sequence):
    dictionary = {'A':'T', 'T':'A', 'G':'C', 'C':'G'}
    reverse = dna_sequence[::-1]
    reverse_comp = ''
    for i in reverse:
        reverse_comp += dictionary[i]
    return reverse_comp

# %%
test_seq = "ATCGAT"
# Out:
# 'A'

# %%
test_seq[0:2]
# Out:
# 'AT'

# %%
def reverse_complement(dna_sequence):
    dictionary = {'A':'T', 'T':'A', 'G':'C', 'C':'G'}
    reverse = dna_sequence[::-1]
    reverse_comp = ''
    for i in reverse:
        reverse_comp += dictionary[i]
    return reverse_comp


def restriction_sites(dna_sequence):
    results = []
    n = len(dna_sequence)

    for length in range(4, 13):     # length = 4, 5, 6, ..., 13
        for i in range(0, n - length + 1):
          #So if starting dna_seq = 7, i in range(0, 7 - 5, 7 - 6, 7 - 7, ..., 7 - 14)
            substring = dna_sequence[i:i+length] #if i = 2, dna_seq[2:9], positions 2 - 8
            if substring == reverse_complement(substring):
                # positions are 1-based
                results.append((i+1, length))

                #Basically, start at each position in the dna_sequence (i)
                #Then find all substrings starting at i that range from 4 - 12
                #Take each of these substrings and see if they have a reverse complement that matches

    return results

# %%
restriction_sites('GCATGCATGGCCTA')
# Out:
# [(2, 4), (4, 4), (6, 4), (9, 4), (1, 6), (3, 6), (2, 8)]
